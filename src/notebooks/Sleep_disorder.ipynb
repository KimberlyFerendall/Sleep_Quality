# %%
#Tratamiento de Datos
import pandas as pd
import numpy as np

#Gráficos
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

#Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_regression, RFE
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import shap
import lime
from lime import lime_tabular
from skopt import BayesSearchCV
from skopt.space import Real, Integer, Categorical

import warnings
warnings.filterwarnings("ignore")

# %%
sleep=pd.read_csv('../data/raw/Sleep.csv')

# %%
df=sleep.copy()

# %%
plt.figure(figsize=(15, 15))

plt.subplot(5,5,1)
sns.scatterplot(x='Age', y='Sleep disorder', data=df, color='teal')
plt.title('Age')

plt.subplot(5,5,2)
sns.scatterplot(x='Sleep duration', y='Sleep disorder', data=df, palette='winter')
plt.title('Sleep Duration')

plt.subplot(5,5,3)
sns.scatterplot(x='Stress level', y='Sleep disorder', data=df, color='blue')
plt.title('Stress Level')

plt.subplot(5,5,4)
sns.scatterplot(x='Heart rate', y='Sleep disorder', data=df, color='teal')
plt.title('Heart Rate')

plt.subplot(5,5,5)
sns.scatterplot(x='Daily steps', y='Sleep disorder', data=df, color='teal')
plt.title('Daily Steps')

plt.subplot(5,5,6)
sns.scatterplot(x='Physical activity', y='Sleep disorder', data=df, color='teal')
plt.title('Physical Activity')

plt.subplot(5,5,7)
sns.scatterplot(x='Height', y='Sleep disorder', data=df, color='teal')
plt.title('Height')

plt.subplot(5,5,8)
sns.scatterplot(x='Weight', y='Sleep disorder', data=df, color='teal')
plt.title('Weight')

plt.subplot(5,5,9)
sns.scatterplot(x='Average screen time', y='Sleep disorder', data=df, color='teal')
plt.title('Screen Time')

plt.subplot(5,5,10)
sns.scatterplot(x='Sleep quality', y='Sleep disorder', data=df, palette='ocean_r')
plt.title('Sleep Quality')

plt.subplot(5,5,11)
sns.boxplot(x='Gender', y='Sleep disorder', data=df, palette='coolwarm_r')
plt.title('Gender')

plt.subplot(5,5,12)
sns.boxplot(x='Blood pressure', y='Sleep disorder', data=df, palette='ocean_r')
plt.title('Blood Pressure')

plt.subplot(5,5,13)
sns.boxplot(x='Wake up during night', y='Sleep disorder', data=df, palette='winter')
plt.title('Wake up at Night')

plt.subplot(5,5,14)
sns.boxplot(x='Feel sleepy during day', y='Sleep disorder', data=df, palette='winter')
plt.title('Sleepy Day')

plt.subplot(5,5,15)
sns.boxplot(x='Caffeine consumption', y='Sleep disorder', data=df, palette='winter')
plt.title('Caffeine')

plt.subplot(5,5,16)
sns.boxplot(x='Alcohol consumption', y='Sleep disorder', data=df, palette='winter')
plt.title('Alchol')

plt.subplot(5,5,17)
sns.boxplot(x='Smoking', y='Sleep disorder', data=df, palette='winter')
plt.title('Smoking')

plt.subplot(5,5,18)
sns.boxplot(x='Medical issue', y='Sleep disorder', data=df, palette='ocean_r')
plt.title('Medical Issue')

plt.subplot(5,5,19)
sns.boxplot(x='Ongoing medication', y='Sleep disorder', data=df, palette='ocean_r')
plt.title('Medication')

plt.subplot(5,5,20)
sns.boxplot(x='Smart device before bed', y='Sleep disorder', data=df, palette='winter')
plt.title('Smart Device')

plt.subplot(5,5,21)
sns.boxplot(x='Blue-light filter', y='Sleep disorder', data=df, palette='winter')
plt.title('Blue-Light')

plt.subplot(5,5,22)
sns.boxplot(x='Discomfort Eye-strain', y='Sleep disorder', data=df, palette='ocean_r')
plt.title('Eye-Strain')

plt.subplot(5,5,23)
sns.boxplot(x='Redness in eye', y='Sleep disorder', data=df, palette='ocean_r')
plt.title('Red Eyes')

plt.subplot(5,5,24)
sns.boxplot(x='Itchiness/Irritation in eye', y='Sleep disorder', data=df, palette='winter')
plt.title('Itchy Eyes')

plt.subplot(5,5,25)
sns.boxplot(x='Dry Eye Disease', y='Sleep disorder', data=df, palette='ocean_r')
plt.title('Dry Eyes')

plt.tight_layout()
plt.show()
